# %% [markdown]
# # Regression
# ## Linear Regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('gapminder.csv')
df.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male    GDP  BMI_female  life  \
# 0    34811059       2.73  0.1   3.328945  24.59620  12314    129.9049  75.3
# 1    19842251       6.43  2.0   1.474353  22.25083   7103    130.1247  58.3
# 2    40381860       2.24  0.5   4.785170  27.50170  14646    118.8915  75.5
# 3     2975029       1.40  0.1   1.804106  25.35542   7383    132.8108  72.5
# 4    21370348       1.96  0.1  18.016313  27.56373  41312    117.3755  81.5
#
#    child_mortality                      Region
# 0             29.5  Middle East & North Africa
# 1            192.0          Sub-Saharan Africa
# 2             15.4                     America
# 3             20.0       Europe & Central Asia
# 4              5.2         East Asia & Pacific

# %%
fig, ax = plt.subplots(figsize=(10,6))
corr = df.corr()
#Pairwise correlation matrix

hm = sns.heatmap(round(corr,2), annot=True, cmap='coolwarm')
fig.subplots_adjust(top=0.93)
t=fig.suptitle('Country Data')

# %%
ax = sns.regplot(y='fertility', x='life', data=df)

# %%
feats = list(df)
feats.remove('life')
#List of features without life expectancy

g = sns.FacetGrid(df, row='life', row_order)


# fig = plt.figure()

# for i in range(1, len(feats)):
#     axs = fig.add_subplot(3,3,i)
#     sns.regplot(x='life', y=feats[i], data=df, ax=axs)
# Out:
# Index(['Europe & Central Asia', 'Sub-Saharan Africa', 'America',
#        'East Asia & Pacific', 'Middle East & North Africa', 'South Asia'],
#       dtype='object')
